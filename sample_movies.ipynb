# %%
import pandas as pd,numpy as np
import matplotlib.pyplot as plt

# %%
m=pd.read_csv('detaset/movies.csv')

# %%
type(m)
# Out:
# pandas.core.frame.DataFrame

# %%
m.sample()
# Out:
#      star_rating  title content_rating   genre  duration  \
# 598          7.7  50/50              R  Comedy       100
#
#                                            actors_list
# 598  [u'Joseph Gordon-Levitt', u'Seth Rogen', u'Ann...

# %%
m.shape
# Out:
# (980, 6)

# %%
m.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
m.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
m
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 975          7.4                                          Tootsie
# 976          7.4                      Back to the Future Part III
# 977          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Poltergeist
# 979          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
m
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
m.describe
# Out:
# <bound method NDFrame.describe of      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 975          7.4                                          Tootsie
# 976          7.4                      Back to the Future Part III
# 977          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Poltergeist
# 979          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# ...

# %%
m.describe(include=['object'])
# Out:
#                                   title content_rating  genre  \
# count                               980            977    980
# unique                              976             12     16
# top     The Girl with the Dragon Tattoo              R  Drama
# freq                                  2            461    279
#
#                                               actors_list
# count                                                 980
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     980 non-null    float64
#  1   title           980 non-null    object
#  2   content_rating  977 non-null    object
#  3   genre           980 non-null    object
#  4   duration        980 non-null    int64
#  5   actors_list     980 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.1+ KB

# %%
m.loc[m.sort_values(by='duration',ascending=False).index.tolist(),['title','duration']].head(3)
# Out:
#                            title  duration
# 477                       Hamlet       242
# 157           Gone with the Wind       238
# 78   Once Upon a Time in America       229

# %%
m[m.title.str.startswith('Once','once')]
# Out:
#      star_rating                         title content_rating    genre  \
# 26           8.6  Once Upon a Time in the West          PG-13  Western
# 78           8.4   Once Upon a Time in America              R    Crime
# 403          7.9                          Once              R    Drama
#
#      duration                                        actors_list
# 26        175  [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 403        85  [u'Glen Hansard', u'Mark\xe9ta Irglov\xe1', u'...

# %%
import re
def check(x):
    m=re.search('^once',x,re.I)
    if m:
        return True
    else:
        return False

# %%
m[m.title.apply(check)]
# Out:
#      star_rating                         title content_rating    genre  \
# 26           8.6  Once Upon a Time in the West          PG-13  Western
# 78           8.4   Once Upon a Time in America              R    Crime
# 401          7.9                          once              R    Drama
# 403          7.9                          Once              R    Drama
#
#      duration                                        actors_list
# 26        175  [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 401        85  [u'Glen Hansard', u'Mark\xe9ta Irglov\xe1', u'...
# 403        85  [u'Glen Hansard', u'Mark\xe9ta Irglov\xe1', u'...

# %%
m.title.apply(str.upper).head()
# Out:
# 0    THE SHAWSHANK REDEMPTION
# 1               THE GODFATHER
# 2      THE GODFATHER: PART II
# 3             THE DARK KNIGHT
# 4                PULP FICTION
# Name: title, dtype: object

# %%
m.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
m[m.content_rating.isnull()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 650          7.7                   Where Eagles Dare            NaN
# 937          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 650     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 937  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
m[m.genre.isin(['Drama','Comedy','Action'])]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# ..           ...                                              ...
# 972          7.4                               Death at a Funeral
# 973          7.4                                   Blue Valentine
# 974          7.4                            The Cider House Rules
# 975          7.4                                          Tootsie
# 977          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 5        NOT RATED   Drama        96
# 9                R   Drama       139
# ...

# %%
m[m.genre.isin(['Drama','Comedy','Action'])].genre.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='genre'>

# %%
m[(m.duration>60)&(m.duration<70)]
# Out:
#      star_rating                        title content_rating    genre  \
# 88           8.4                      The Kid      NOT RATED   Comedy
# 258          8.1  The Cabinet of Dr. Caligari        UNRATED    Crime
# 293          8.1                    Duck Soup         PASSED   Comedy
# 338          8.0          Battleship Potemkin        UNRATED  History
# 389          8.0                       Freaks        UNRATED    Drama
# 743          7.6                    Following              R  Mystery
#
#      duration                                        actors_list
# 88         68  [u'Charles Chaplin', u'Edna Purviance', u'Jack...
# 258        67  [u'Werner Krauss', u'Conrad Veidt', u'Friedric...
# 293        68    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
# 338        66  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...
# 389        64  [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...
# 743        69  [u'Jeremy Theobald', u'Alex Haw', u'Lucy Russe...

# %%
m[m.duration.isin(range(60,70))].genre.value_counts()
# Out:
# genre
# Comedy     2
# Crime      1
# History    1
# Drama      1
# Mystery    1
# Name: count, dtype: int64

# %%
m[m.duration.isin(range(60,70))].genre.value_counts().plot(kind='barh')
plt.show()

# %%
m[m.star_rating>8]
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 3            9.0           The Dark Knight          PG-13     Action
# 4            8.9              Pulp Fiction              R      Crime
# ..           ...                       ...            ...        ...
# 292          8.1  The Manchurian Candidate       APPROVED    Mystery
# 293          8.1                 Duck Soup         PASSED     Comedy
# 294          8.1      Beauty and the Beast              G  Animation
# 295          8.1           The Truman Show             PG      Drama
# 296          8.1            The Wild Bunch              R     Action
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
m[m.star_rating>8].shape
# Out:
# (297, 6)

# %%
m[m.star_rating>8].genre.value_counts()
# Out:
# genre
# Drama        92
# Crime        43
# Comedy       38
# Action       37
# Adventure    25
# Biography    20
# Animation    18
# Mystery       9
# Western       7
# Horror        5
# Film-Noir     2
# Sci-Fi        1
# Name: count, dtype: int64

# %%
m.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
m.genre.nunique()
# Out:
# 16
